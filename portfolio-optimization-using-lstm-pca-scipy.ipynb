# %% [markdown]
# ### Ensuring GPU is Available

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4932490347562536230
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11345264640
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8341776446065018709
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Import packages
import pathlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as sci_opt
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
from pprint import pprint
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# %matplotlib inline
# Set some display options for Pandas.
pd.set_option('display.max_colwidth', -1)
pd.set_option('expand_frame_repr', False)
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.63.tar.gz (26 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 14.6 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23918 sha256=716103727db292011f7d32d1fc8b93a10b99b677a29a0af5cc45984eacfecedf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8q3r17hn/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.3 yfinance-0.1.63
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
# Define the symbols
# At different points, we will need to generate metrics based on the number
# of symbols we have, so let's save some time and just calculate that now.
# Read and print the stock tickers 


# Get the data for this tickers from yahoo finance

tickers=["BAC","IBM","PFE","TSLA","XOM"]
number_of_symbols = len(tickers)
Stocks_hist=yf.download(tickers,interval='1d',start='2015-01-01',end='2020-12-31', auto_adjust=True, group_by='ticker',index=False)
Stocks_hist = Stocks_hist.stack(level=0).rename_axis(['Date', 'Index']).reset_index(level=1)
Stocks_hist.to_csv('StockPrices.csv')
price_data_frame = pd.read_csv('StockPrices.csv')#,delimiter=',')
print('Loaded data from the Stocks repository')

# Print the head.
print(price_data_frame.head())
# Out:
# [*********************100%***********************]  5 of 5 completed
# Loaded data from the Stocks repository
#          Date Index       Close        High         Low        Open    Volume
# 0  2015-01-02  BAC   15.880880   15.996217   15.685697   15.960728   48951100
# 1  2015-01-02  IBM   121.796097  122.735534  120.999456  121.232435  5525500
# 2  2015-01-02  PFE   23.154585   23.487159   23.073289   23.110243   16371571
# 3  2015-01-02  TSLA  43.862000   44.650002   42.652000   44.574001   23822000
# 4  2015-01-02  XOM   67.654991   67.815329   66.911607   67.232283   10220400

# %% [markdown]
# ### Data Pulling

# %%
price_data_frame['Date']= pd.to_datetime(price_data_frame['Date'])
df_close = price_data_frame[['Date', 'Index', 'Close']]
df_close.head(5)
# Out:
#         Date Index       Close
# 0 2015-01-02  BAC   15.880880
# 1 2015-01-02  IBM   121.796097
# 2 2015-01-02  PFE   23.154585
# 3 2015-01-02  TSLA  43.862000
# 4 2015-01-02  XOM   67.654991

# %%
df_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7550 entries, 0 to 7549
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7550 non-null   datetime64[ns]
#  1   Index   7550 non-null   object
#  2   Close   7550 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 177.1+ KB

# %%
df_close = df_close.pivot_table(index = 'Date', columns = 'Index', values = 'Close').dropna(axis=1)
stocks_tickers = df_close.columns
print(stocks_tickers)
# Out:
# Index(['BAC', 'IBM', 'PFE', 'TSLA', 'XOM'], dtype='object', name='Index')

# %%
#Saving Trading Days
dates = df_close.index

#Saving Stocks
stocks = df_close.columns
df_close.shape
# Out:
# (1510, 5)

# %% [markdown]
# # Feature Engineering

# %%
raw_df=yf.download(tickers,interval='1d',start='2015-01-01',end='2020-12-31', auto_adjust=True, group_by='ticker',index=False)
raw_df.head(5)
raw_df = raw_df.dropna(axis = 1)
raw_df.tail(5)
# Out:
# [*********************100%***********************]  5 of 5 completed
#                   XOM                                                   PFE                                                   TSLA                                                       IBM                                                     BAC
#                  Open       High        Low      Close    Volume       Open       High        Low      Close    Volume        Open        High         Low       Close    Volume        Open        High         Low       Close   Volume       Open       High        Low      Close    Volume
# Date
# 2020-12-23  39.630914  40.471079  39.583178  39.879147  19085900  35.929063  36.550374  35.802862  36.346504  36182000  632.200012  651.500000  622.570007  645.979980  33173000  119.519640  120.802828  119.384569  119.538940  2693900  29.122153  30.073405  29.062701  29.776138  52537200
# 2020-12-24  39.764578  39.955522  39.506800  39.716839  8039000   36.307677  36.472710  36.094101  36.181473  14790100  642.989990  666.090027  641.000000  661.770020  22865600  120.600218  120.696697  119.838024  120.301132  1761100  29.994134  29.994134  29.468964  29.686958  22632300
# 2020-12-28  39.802766  40.623836  39.640464  39.850506  23877500  36.268843  36.482419  35.608703  35.744614  26993700  674.510010  681.400024  660.799988  663.690002  32278600  120.696703  122.143905  120.079230  120.426559  3615200  29.954499  30.271582  29.716686  29.855410  32861200
# 2020-12-29  40.136927  40.213304  39.334952  39.401783  20287700  35.822279  36.113516  35.715491  35.967896  23152100  661.000000  669.900024  655.000000  665.989990  22910800  120.937905  121.063334  118.902173  119.442467  3487000  29.895045  29.974316  29.657233  29.736504  33291900
# 2020-12-30  39.459064  40.499719  39.401779  39.716839  23807300  35.948477  36.152347  35.628118  35.666950  24889800  672.000000  696.599976  668.359985  694.780029  42846000  119.442469  120.455506  119.278447  119.963455  3380300  29.726594  29.944588  29.667141  29.706776  26370100

# %%
raw_df.head(5)
# Out:
#                   XOM                                                   PFE                                                  TSLA                                                    IBM                                                     BAC
#                  Open       High        Low      Close    Volume       Open       High        Low      Close    Volume       Open       High        Low      Close    Volume        Open        High         Low       Close   Volume       Open       High        Low      Close     Volume
# Date
# 2015-01-02  67.232283  67.815329  66.911607  67.654991  10220400  23.110243  23.487159  23.073289  23.154585  16371571  44.574001  44.650002  42.652000  43.862000  23822000  121.232435  122.735534  120.999456  121.796097  5525500  15.960728  15.996217  15.685697  15.880880  48951100
# 2015-01-05  67.122953  67.341597  65.228061  65.803818  18502400  23.169373  23.213716  22.918093  23.028952  24786391  42.910000  43.299999  41.431999  42.018002  26842500  121.202365  121.202365  119.639141  119.879631  4880400  15.783284  15.801027  15.339684  15.419531  105605500
# 2015-01-06  65.767381  66.620088  64.878238  65.453995  16670700  23.110247  23.546288  22.999389  23.221106  29468681  42.012001  42.840000  40.841999  42.256001  31309500  119.999867  120.217822  116.617895  117.294296  6146700  15.455021  15.472766  14.887214  14.958190  144912400
# 2015-01-07  66.066209  66.671119  65.592485  66.117226  13590700  23.442824  23.553682  23.339356  23.538900  20248816  42.669998  42.956001  41.956001  42.189999  14842000  118.143559  118.143559  115.761149  116.527733  4701800  15.206608  15.242097  14.967065  15.029169  104603800
# 2015-01-08  66.503466  67.246844  66.321264  67.217697  15487500  23.901035  24.122753  23.812349  24.019285  49169522  42.562000  42.759998  42.001999  42.124001  17212500  117.422061  119.526389  116.903490  119.060432  4236800  15.224351  15.384048  15.171120  15.339688  73388500

# %%
raw_df.tail(5)
# Out:
#                   XOM                                                   PFE                                                   TSLA                                                       IBM                                                     BAC
#                  Open       High        Low      Close    Volume       Open       High        Low      Close    Volume        Open        High         Low       Close    Volume        Open        High         Low       Close   Volume       Open       High        Low      Close    Volume
# Date
# 2020-12-23  39.630914  40.471079  39.583178  39.879147  19085900  35.929063  36.550374  35.802862  36.346504  36182000  632.200012  651.500000  622.570007  645.979980  33173000  119.519640  120.802828  119.384569  119.538940  2693900  29.122153  30.073405  29.062701  29.776138  52537200
# 2020-12-24  39.764578  39.955522  39.506800  39.716839  8039000   36.307677  36.472710  36.094101  36.181473  14790100  642.989990  666.090027  641.000000  661.770020  22865600  120.600218  120.696697  119.838024  120.301132  1761100  29.994134  29.994134  29.468964  29.686958  22632300
# 2020-12-28  39.802766  40.623836  39.640464  39.850506  23877500  36.268843  36.482419  35.608703  35.744614  26993700  674.510010  681.400024  660.799988  663.690002  32278600  120.696703  122.143905  120.079230  120.426559  3615200  29.954499  30.271582  29.716686  29.855410  32861200
# 2020-12-29  40.136927  40.213304  39.334952  39.401783  20287700  35.822279  36.113516  35.715491  35.967896  23152100  661.000000  669.900024  655.000000  665.989990  22910800  120.937905  121.063334  118.902173  119.442467  3487000  29.895045  29.974316  29.657233  29.736504  33291900
# 2020-12-30  39.459064  40.499719  39.401779  39.716839  23807300  35.948477  36.152347  35.628118  35.666950  24889800  672.000000  696.599976  668.359985  694.780029  42846000  119.442469  120.455506  119.278447  119.963455  3380300  29.726594  29.944588  29.667141  29.706776  26370100

# %%
raw_df.shape
# Out:
# (1510, 25)

# %%
#DROP ROWS WITH NA vals 
full_feature_dataset = raw_df.dropna(axis=0)

# %% [markdown]
# # Principal Component Analysis

# %%
full_feature_dataset.head()
# Out:
#                   XOM                                                   PFE                                                  TSLA                                                    IBM                                                     BAC
#                  Open       High        Low      Close    Volume       Open       High        Low      Close    Volume       Open       High        Low      Close    Volume        Open        High         Low       Close   Volume       Open       High        Low      Close     Volume
# Date
# 2015-01-02  67.232283  67.815329  66.911607  67.654991  10220400  23.110243  23.487159  23.073289  23.154585  16371571  44.574001  44.650002  42.652000  43.862000  23822000  121.232435  122.735534  120.999456  121.796097  5525500  15.960728  15.996217  15.685697  15.880880  48951100
# 2015-01-05  67.122953  67.341597  65.228061  65.803818  18502400  23.169373  23.213716  22.918093  23.028952  24786391  42.910000  43.299999  41.431999  42.018002  26842500  121.202365  121.202365  119.639141  119.879631  4880400  15.783284  15.801027  15.339684  15.419531  105605500
# 2015-01-06  65.767381  66.620088  64.878238  65.453995  16670700  23.110247  23.546288  22.999389  23.221106  29468681  42.012001  42.840000  40.841999  42.256001  31309500  119.999867  120.217822  116.617895  117.294296  6146700  15.455021  15.472766  14.887214  14.958190  144912400
# 2015-01-07  66.066209  66.671119  65.592485  66.117226  13590700  23.442824  23.553682  23.339356  23.538900  20248816  42.669998  42.956001  41.956001  42.189999  14842000  118.143559  118.143559  115.761149  116.527733  4701800  15.206608  15.242097  14.967065  15.029169  104603800
# 2015-01-08  66.503466  67.246844  66.321264  67.217697  15487500  23.901035  24.122753  23.812349  24.019285  49169522  42.562000  42.759998  42.001999  42.124001  17212500  117.422061  119.526389  116.903490  119.060432  4236800  15.224351  15.384048  15.171120  15.339688  73388500

# %%
full_feature_dataset.tail(5)
# Out:
#                   XOM                                                   PFE                                                   TSLA                                                       IBM                                                     BAC
#                  Open       High        Low      Close    Volume       Open       High        Low      Close    Volume        Open        High         Low       Close    Volume        Open        High         Low       Close   Volume       Open       High        Low      Close    Volume
# Date
# 2020-12-23  39.630914  40.471079  39.583178  39.879147  19085900  35.929063  36.550374  35.802862  36.346504  36182000  632.200012  651.500000  622.570007  645.979980  33173000  119.519640  120.802828  119.384569  119.538940  2693900  29.122153  30.073405  29.062701  29.776138  52537200
# 2020-12-24  39.764578  39.955522  39.506800  39.716839  8039000   36.307677  36.472710  36.094101  36.181473  14790100  642.989990  666.090027  641.000000  661.770020  22865600  120.600218  120.696697  119.838024  120.301132  1761100  29.994134  29.994134  29.468964  29.686958  22632300
# 2020-12-28  39.802766  40.623836  39.640464  39.850506  23877500  36.268843  36.482419  35.608703  35.744614  26993700  674.510010  681.400024  660.799988  663.690002  32278600  120.696703  122.143905  120.079230  120.426559  3615200  29.954499  30.271582  29.716686  29.855410  32861200
# 2020-12-29  40.136927  40.213304  39.334952  39.401783  20287700  35.822279  36.113516  35.715491  35.967896  23152100  661.000000  669.900024  655.000000  665.989990  22910800  120.937905  121.063334  118.902173  119.442467  3487000  29.895045  29.974316  29.657233  29.736504  33291900
# 2020-12-30  39.459064  40.499719  39.401779  39.716839  23807300  35.948477  36.152347  35.628118  35.666950  24889800  672.000000  696.599976  668.359985  694.780029  42846000  119.442469  120.455506  119.278447  119.963455  3380300  29.726594  29.944588  29.667141  29.706776  26370100

# %%
full_feature_dataset = full_feature_dataset.to_numpy()
full_feature_dataset.shape
# Out:
# (1510, 25)

# %% [markdown]
# ### Performing PCA to Extract most useful features for the dataset

# %%
closing_prices = df_close.iloc[:full_feature_dataset.shape[0],:]

# %% [markdown]
# Creating train and test sets

# %%
from sklearn.model_selection import train_test_split

#Division of data
array_train, array_test = train_test_split(closing_prices, shuffle = False, test_size = .2)
PCA_train, PCA_test = train_test_split(full_feature_dataset, shuffle = False, test_size = .2)

# %%
print(array_train.shape)
print(PCA_train.shape)
# Out:
# (1208, 5)
# (1208, 25)

# %%
from sklearn.decomposition import PCA
pc3 = PCA()
temp = pc3.fit_transform(PCA_train)

# %% [markdown]
# ###Nearly all data is explained by 5 components

# %%
plt.plot(np.cumsum(pc3.explained_variance_ratio_))
plt.xlabel('Num Components')
plt.ylabel('Cumulative Explained Variance');

# %% [markdown]
# ## Data Manipulation
#
# In this section several steps are performed...
# - Set our lookback/training window and horizon/testing window
# - Scale the data using MinMaxScaler
# - Create a training, validation, and test set
# - Process data into arrays with ranges of dates from (lookback, t) and (t+1, horizon). T jumps by one day each time.

# %% [markdown]
# Setting lookback and horizon window sizes

# %%
num_companies = df_close.shape[1]
lookback = 180 #How many days of the past can the model see
horizon = 22 #How many days into the future are we trying to predict

# %% [markdown]
# Scaling the Data

# %%
#Data with only closing prices
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.preprocessing import MinMaxScaler


scl_array_train = MinMaxScaler(feature_range=(0,1))
scl_array_test = MinMaxScaler(feature_range=(0,1))

array_train = scl_array_train.fit_transform(array_train)
array_test  = scl_array_test.fit_transform(array_test) #[0,1]

#Full features dataset; reducing dimensionality here
from sklearn.decomposition import PCA
Train_scl = MinMaxScaler(feature_range=(0,1))
Test_scl  = MinMaxScaler(feature_range=(0,1))

pcaTrain = PCA(n_components =  len(tickers))
pcaTest = PCA(n_components =  len(tickers))

PCA_train = Train_scl.fit_transform(PCA_train)
PCA_train = pcaTrain.fit_transform(PCA_train)

PCA_test = Test_scl.fit_transform(PCA_test)
PCA_test = pcaTest.fit_transform(PCA_test)

# %%
print(array_train.shape)
print(PCA_train.shape)
# Out:
# (1208, 5)
# (1208, 5)

# %% [markdown]
# Creating function to iteravely process data

# %%
#Get the data and splits in input X and output Y, by spliting in lookback number of past days as input X 
#and horizon number of coming days as Y.
def processData(data, lookback, horizon,num_companies,jump=1):
    X,Y = [],[]
    for i in range(0,len(data) -lookback - horizon +1, jump):
        X.append(data[i:(i+lookback)])
        Y.append(data[(i+lookback):(i+lookback+horizon)])
    return np.array(X),np.array(Y)

# %% [markdown]
# Further splitting the train data into training and validation sets

# %%
# Formation of lookback dataframes and forward dataframes for training, and testing dataset
# to calculate accuracy

#Testing Data
X_test, void = processData(PCA_test,lookback,horizon,num_companies,horizon)
void, y_test = processData(array_test,lookback,horizon,num_companies,horizon) 
y_test = np.array([list(a.ravel()) for a in y_test])

#Training/Validation Data
X_PCA, void = processData(PCA_train,lookback,horizon,num_companies)
void, y = processData(array_train,lookback,horizon,num_companies)
y = np.array([list(x.ravel()) for x in y])

X_train, X_validate, y_train, y_validate = train_test_split(X_PCA, y, test_size=0.20, random_state=0)

# %%
print(X_train.shape)
print(X_validate.shape)
print(X_test.shape)
print(y_train.shape)
print(y_validate.shape)
print(y_test.shape)
#(Sample,Timestep,Features)
# Out:
# (805, 180, 5)
# (202, 180, 5)
# (5, 180, 5)
# (805, 110)
# (202, 110)
# (5, 110)

# %% [markdown]
# # LSTM Stock Prediction

# %% [markdown]
# ## Model Architecture + Training
#
# Here, we can input the number or neurons on each layer, change the level of dropout, and set the specifications for early dropout. The model is then trained and the learning curve is plotted below.

# %%
import keras
from keras.models import Sequential, load_model
import tensorflow as tf
from keras.layers import LSTM,Dense,Activation,Attention,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers


#Model Architecture - Two LSTM layers with x neurons & y epochs
num_neurons_L1 =800
num_neurons_L2 =600
EPOCHS = 50
optimizer = keras.optimizers.Adam(learning_rate=0.001)
#Model
model = Sequential()
model.add(LSTM(num_neurons_L1,input_shape=(lookback,num_companies), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(num_neurons_L2,input_shape=(num_neurons_L1,1)))
model.add(Dense(horizon * num_companies, activation = 'relu'))
model.add(Dense(horizon * num_companies, activation = 'relu'))
model.compile(loss='mean_squared_error', optimizer= optimizer, metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 180, 800)          2579200
# _________________________________________________________________
# dropout (Dropout)            (None, 180, 800)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 600)               3362400
# _________________________________________________________________
# dense (Dense)                (None, 110)               66110
# _________________________________________________________________
# dense_1 (Dense)              (None, 110)               12210
# =================================================================
# Total params: 6,019,920
# Trainable params: 6,019,920
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Early stopping severly *underfits* the data, we are going for better results
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=4)

for iter in range(100):
  print("Iternation # : ", iter)
  history = model.fit(X_train,y_train,epochs=EPOCHS,
                      validation_data=(X_validate,y_validate),
                      shuffle=False,batch_size=32,callbacks= [callback],verbose=2)
# Out:
# Iternation # :  0
# Epoch 1/50
# 26/26 - 16s - loss: 0.1549 - accuracy: 0.0298 - val_loss: 0.0878 - val_accuracy: 0.0297
# Epoch 2/50
# 26/26 - 7s - loss: 0.0772 - accuracy: 0.0273 - val_loss: 0.0716 - val_accuracy: 0.0297
# Epoch 3/50
# 26/26 - 7s - loss: 0.0666 - accuracy: 0.0311 - val_loss: 0.0666 - val_accuracy: 0.0396
# Epoch 4/50
# 26/26 - 7s - loss: 0.0626 - accuracy: 0.0385 - val_loss: 0.0629 - val_accuracy: 0.0495
# Epoch 5/50
# 26/26 - 7s - loss: 0.0594 - accuracy: 0.0348 - val_loss: 0.0595 - val_accuracy: 0.0594
# Epoch 6/50
# 26/26 - 7s - loss: 0.0572 - accuracy: 0.0373 - val_loss: 0.0590 - val_accuracy: 0.0545
# Epoch 7/50
# 26/26 - 7s - loss: 0.0563 - accuracy: 0.0373 - val_loss: 0.0586 - val_accuracy: 0.0297
# Epoch 8/50
# 26/26 - 7s - loss: 0.0555 - accuracy: 0.0410 - val_loss: 0.0585 - val_accuracy: 0.0248
# Epoch 9/50
# 26/26 - 7s - loss: 0.0557 - accuracy: 0.0460 - val_loss: 0.0590 - val_accuracy: 0.0347
# Epoch 10/50
# 26/26 - 7s - loss: 0.0508 - accuracy: 0.0484 - val_loss: 0.0457 - val_accuracy: 0.0495
# Epoch 11/50
# 26/26 - 7s - loss: 0.0423 - accuracy: 0.0509 - val_loss: 0.0414 - val_accuracy: 0.0347
# Epoch 12/50
# 26/26 - 7s - loss: 0.0384 - accuracy: 0.0509 - val_loss: 0.0374 - val_accuracy: 0.0446
# Epoch 13/50
# 26/26 - 7s - loss: 0.0362 - accuracy: 0.0646 - val_loss: 0.0365 - val_accuracy: 0.0446
# Epoch 14/50
# 26/26 - 7s - loss: 0.0348 - accuracy: 0.0646 - val_loss: 0.0345 - val_accuracy: 0.0545
# Epoch 15/50
# 26/26 - 7s - loss: 0.0333 - accuracy: 0.0907 - val_loss: 0.0337 - val_accuracy: 0.0693
# Epoch 16/50
# 26/26 - 7s - loss: 0.0331 - accuracy: 0.0671 - val_loss: 0.0334 - val_accuracy: 0.0545
# Epoch 17/50
# 26/26 - 7s - loss: 0.0327 - accuracy: 0.0795 - val_loss: 0.0333 - val_accuracy: 0.0644
# Epoch 18/50
# 26/26 - 7s - loss: 0.0326 - accuracy: 0.0770 - val_loss: 0.0331 - val_accuracy: 0.0594
# Epoch 19/50
# 26/26 - 7s - loss: 0.0322 - accuracy: 0.0770 - val_loss: 0.0331 - val_accuracy: 0.0743
# Epoch 20/50
# 26/26 - 7s - loss: 0.0321 - accuracy: 0.0957 - val_loss: 0.0328 - val_accuracy: 0.0743
# Epoch 21/50
# 26/26 - 7s - loss: 0.0321 - accuracy: 0.0919 - val_loss: 0.0328 - val_accuracy: 0.0743
# Epoch 22/50
# 26/26 - 7s - loss: 0.0320 - accuracy: 0.0957 - val_loss: 0.0328 - val_accuracy: 0.0792
# Epoch 23/50
# 26/26 - 7s - loss: 0.0320 - accuracy: 0.0807 - val_loss: 0.0327 - val_accuracy: 0.0545
# Epoch 24/50
# 26/26 - 7s - loss: 0.0319 - accuracy: 0.0845 - val_loss: 0.0324 - val_accuracy: 0.0743
# Epoch 25/50
# 26/26 - 7s - loss: 0.0317 - accuracy: 0.0907 - val_loss: 0.0324 - val_accuracy: 0.0842
# Epoch 26/50
# 26/26 - 7s - loss: 0.0312 - accuracy: 0.0832 - val_loss: 0.0311 - val_accuracy: 0.0693
# Epoch 27/50
# 26/26 - 7s - loss: 0.0292 - accuracy: 0.0783 - val_loss: 0.0281 - val_accuracy: 0.0891
# Epoch 28/50
# 26/26 - 7s - loss: 0.0273 - accuracy: 0.0870 - val_loss: 0.0277 - val_accuracy: 0.0743
# Epoch 29/50
# 26/26 - 7s - loss: 0.0270 - accuracy: 0.1081 - val_loss: 0.0278 - val_accuracy: 0.0941
# Epoch 30/50
# 26/26 - 7s - loss: 0.0271 - accuracy: 0.0932 - val_loss: 0.0279 - val_accuracy: 0.0743
# Epoch 31/50
# 26/26 - 7s - loss: 0.0270 - accuracy: 0.0957 - val_loss: 0.0276 - val_accuracy: 0.0941
# Epoch 32/50
# 26/26 - 7s - loss: 0.0269 - accuracy: 0.1180 - val_loss: 0.0273 - val_accuracy: 0.0594
# Epoch 33/50
# 26/26 - 7s - loss: 0.0261 - accuracy: 0.1168 - val_loss: 0.0264 - val_accuracy: 0.0891
# Epoch 34/50
# 26/26 - 7s - loss: 0.0257 - accuracy: 0.0944 - val_loss: 0.0263 - val_accuracy: 0.0693
# Epoch 35/50
# 26/26 - 7s - loss: 0.0256 - accuracy: 0.0957 - val_loss: 0.0262 - val_accuracy: 0.0842
# Epoch 36/50
# 26/26 - 7s - loss: 0.0256 - accuracy: 0.1056 - val_loss: 0.0258 - val_accuracy: 0.0891
# Epoch 37/50
# 26/26 - 7s - loss: 0.0250 - accuracy: 0.1168 - val_loss: 0.0256 - val_accuracy: 0.0594
# Epoch 38/50
# 26/26 - 7s - loss: 0.0250 - accuracy: 0.1130 - val_loss: 0.0254 - val_accuracy: 0.0644
# Epoch 39/50
# 26/26 - 7s - loss: 0.0246 - accuracy: 0.1081 - val_loss: 0.0254 - val_accuracy: 0.0941
# Epoch 40/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1255 - val_loss: 0.0254 - val_accuracy: 0.0941
# Epoch 41/50
# 26/26 - 7s - loss: 0.0246 - accuracy: 0.1155 - val_loss: 0.0253 - val_accuracy: 0.0693
# Epoch 42/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1155 - val_loss: 0.0251 - val_accuracy: 0.0644
# Epoch 43/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1143 - val_loss: 0.0252 - val_accuracy: 0.1139
# Epoch 44/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1205 - val_loss: 0.0253 - val_accuracy: 0.0693
# Epoch 45/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1217 - val_loss: 0.0252 - val_accuracy: 0.0792
# Epoch 46/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1093 - val_loss: 0.0253 - val_accuracy: 0.0891
# Epoch 47/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1193 - val_loss: 0.0253 - val_accuracy: 0.1139
# Epoch 48/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1217 - val_loss: 0.0255 - val_accuracy: 0.0792
# Epoch 49/50
# 26/26 - 7s - loss: 0.0245 - accuracy: 0.1006 - val_loss: 0.0249 - val_accuracy: 0.0941
# Iternation # :  1
# Epoch 1/50
# 26/26 - 7s - loss: 0.0242 - accuracy: 0.1093 - val_loss: 0.0245 - val_accuracy: 0.1089
# Epoch 2/50
# 26/26 - 7s - loss: 0.0240 - accuracy: 0.1267 - val_loss: 0.0248 - val_accuracy: 0.0693
# Epoch 3/50
# 26/26 - 7s - loss: 0.0240 - accuracy: 0.1255 - val_loss: 0.0246 - val_accuracy: 0.0792
# Epoch 4/50
# 26/26 - 7s - loss: 0.0241 - accuracy: 0.1230 - val_loss: 0.0245 - val_accuracy: 0.0842
# Epoch 5/50
# 26/26 - 7s - loss: 0.0240 - accuracy: 0.1317 - val_loss: 0.0246 - val_accuracy: 0.0891
# Epoch 6/50
# 26/26 - 7s - loss: 0.0241 - accuracy: 0.1366 - val_loss: 0.0247 - val_accuracy: 0.1089
# Iternation # :  2
# Epoch 1/50
# 26/26 - 7s - loss: 0.0243 - accuracy: 0.1217 - val_loss: 0.0250 - val_accuracy: 0.1089
# Epoch 2/50
# 26/26 - 7s - loss: 0.0242 - accuracy: 0.1230 - val_loss: 0.0250 - val_accuracy: 0.0842
# Epoch 3/50
# 26/26 - 7s - loss: 0.0240 - accuracy: 0.1217 - val_loss: 0.0235 - val_accuracy: 0.0941
# Epoch 4/50
# 26/26 - 7s - loss: 0.0222 - accuracy: 0.1354 - val_loss: 0.0225 - val_accuracy: 0.0594
# Epoch 5/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1304 - val_loss: 0.0224 - val_accuracy: 0.0792
# Epoch 6/50
# 26/26 - 7s - loss: 0.0218 - accuracy: 0.1578 - val_loss: 0.0225 - val_accuracy: 0.0743
# Epoch 7/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1342 - val_loss: 0.0225 - val_accuracy: 0.0792
# Epoch 8/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1553 - val_loss: 0.0225 - val_accuracy: 0.0693
# Epoch 9/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1280 - val_loss: 0.0224 - val_accuracy: 0.0941
# Epoch 10/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1516 - val_loss: 0.0225 - val_accuracy: 0.0594
# Iternation # :  3
# Epoch 1/50
# 26/26 - 7s - loss: 0.0219 - accuracy: 0.1466 - val_loss: 0.0225 - val_accuracy: 0.0693
# Epoch 2/50
# 26/26 - 7s - loss: 0.0217 - accuracy: 0.1391 - val_loss: 0.0217 - val_accuracy: 0.0941
# Epoch 3/50
# 26/26 - 7s - loss: 0.0213 - accuracy: 0.1304 - val_loss: 0.0217 - val_accuracy: 0.1089
# Epoch 4/50
# 26/26 - 7s - loss: 0.0211 - accuracy: 0.1304 - val_loss: 0.0216 - val_accuracy: 0.1139
# Epoch 5/50
# 26/26 - 7s - loss: 0.0212 - accuracy: 0.1366 - val_loss: 0.0218 - val_accuracy: 0.0941
# Epoch 6/50
# 26/26 - 7s - loss: 0.0209 - accuracy: 0.1230 - val_loss: 0.0197 - val_accuracy: 0.1139
# Epoch 7/50
# 26/26 - 7s - loss: 0.0185 - accuracy: 0.1106 - val_loss: 0.0191 - val_accuracy: 0.0693
# Epoch 8/50
# 26/26 - 7s - loss: 0.0179 - accuracy: 0.1130 - val_loss: 0.0186 - val_accuracy: 0.1139
# Epoch 9/50
# 26/26 - 7s - loss: 0.0177 - accuracy: 0.1491 - val_loss: 0.0184 - val_accuracy: 0.1089
# Epoch 10/50
# 26/26 - 7s - loss: 0.0176 - accuracy: 0.1366 - val_loss: 0.0185 - val_accuracy: 0.0842
# Epoch 11/50
# 26/26 - 7s - loss: 0.0176 - accuracy: 0.1379 - val_loss: 0.0184 - val_accuracy: 0.1139
# Epoch 12/50
# 26/26 - 7s - loss: 0.0176 - accuracy: 0.1416 - val_loss: 0.0185 - val_accuracy: 0.0891
# Epoch 13/50
# 26/26 - 7s - loss: 0.0176 - accuracy: 0.1503 - val_loss: 0.0183 - val_accuracy: 0.0842
# Epoch 14/50
# 26/26 - 7s - loss: 0.0175 - accuracy: 0.1354 - val_loss: 0.0183 - val_accuracy: 0.1188
# Epoch 15/50
# 26/26 - 7s - loss: 0.0175 - accuracy: 0.1429 - val_loss: 0.0183 - val_accuracy: 0.1139
# Epoch 16/50
# 26/26 - 7s - loss: 0.0174 - accuracy: 0.1416 - val_loss: 0.0182 - val_accuracy: 0.0990
# Epoch 17/50
# 26/26 - 7s - loss: 0.0174 - accuracy: 0.1578 - val_loss: 0.0182 - val_accuracy: 0.1188
# Epoch 18/50
# 26/26 - 7s - loss: 0.0175 - accuracy: 0.1590 - val_loss: 0.0183 - val_accuracy: 0.1287
# Epoch 19/50
# 26/26 - 7s - loss: 0.0175 - accuracy: 0.1491 - val_loss: 0.0183 - val_accuracy: 0.0891
# Epoch 20/50
# 26/26 - 7s - loss: 0.0175 - accuracy: 0.1689 - val_loss: 0.0182 - val_accuracy: 0.1238
# Iternation # :  4
# Epoch 1/50
# 26/26 - 7s - loss: 0.0171 - accuracy: 0.1714 - val_loss: 0.0164 - val_accuracy: 0.0941
# Epoch 2/50
# 26/26 - 7s - loss: 0.0156 - accuracy: 0.1366 - val_loss: 0.0161 - val_accuracy: 0.0891
# Epoch 3/50
# 26/26 - 7s - loss: 0.0155 - accuracy: 0.1466 - val_loss: 0.0160 - val_accuracy: 0.1040
# Epoch 4/50
# 26/26 - 7s - loss: 0.0155 - accuracy: 0.1528 - val_loss: 0.0160 - val_accuracy: 0.1139
# Epoch 5/50
# 26/26 - 7s - loss: 0.0154 - accuracy: 0.1503 - val_loss: 0.0160 - val_accuracy: 0.1337
# Epoch 6/50
# 26/26 - 7s - loss: 0.0154 - accuracy: 0.1640 - val_loss: 0.0160 - val_accuracy: 0.1089
# Epoch 7/50
# 26/26 - 7s - loss: 0.0154 - accuracy: 0.1615 - val_loss: 0.0160 - val_accuracy: 0.1139
# Epoch 8/50
# 26/26 - 7s - loss: 0.0153 - accuracy: 0.1565 - val_loss: 0.0162 - val_accuracy: 0.1089
# Epoch 9/50
# 26/26 - 7s - loss: 0.0157 - accuracy: 0.1652 - val_loss: 0.0163 - val_accuracy: 0.1089
# Epoch 10/50
# 26/26 - 7s - loss: 0.0157 - accuracy: 0.1553 - val_loss: 0.0162 - val_accuracy: 0.1089
# Epoch 11/50
# 26/26 - 7s - loss: 0.0156 - accuracy: 0.1590 - val_loss: 0.0163 - val_accuracy: 0.0990
# Epoch 12/50
# 26/26 - 7s - loss: 0.0161 - accuracy: 0.1640 - val_loss: 0.0177 - val_accuracy: 0.1238
# Iternation # :  5
# Epoch 1/50
# 26/26 - 7s - loss: 0.0171 - accuracy: 0.0845 - val_loss: 0.0189 - val_accuracy: 0.0743
# Epoch 2/50
# 26/26 - 7s - loss: 0.0561 - accuracy: 0.0286 - val_loss: 0.0863 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 26/26 - 7s - loss: 0.0573 - accuracy: 0.0124 - val_loss: 0.0399 - val_accuracy: 0.0149
# Epoch 4/50
# 26/26 - 7s - loss: 0.0303 - accuracy: 0.0472 - val_loss: 0.0303 - val_accuracy: 0.0099
# Epoch 5/50
# 26/26 - 7s - loss: 0.0267 - accuracy: 0.0348 - val_loss: 0.0235 - val_accuracy: 0.0495
# Iternation # :  6
# Epoch 1/50
# 26/26 - 7s - loss: 0.0191 - accuracy: 0.0460 - val_loss: 0.0182 - val_accuracy: 0.0396
# Epoch 2/50
# 26/26 - 7s - loss: 0.0149 - accuracy: 0.0410 - val_loss: 0.0135 - val_accuracy: 0.0347
# Epoch 3/50
# 26/26 - 7s - loss: 0.0130 - accuracy: 0.0621 - val_loss: 0.0130 - val_accuracy: 0.0545
# Epoch 4/50
# 26/26 - 7s - loss: 0.0123 - accuracy: 0.0571 - val_loss: 0.0125 - val_accuracy: 0.0495
# Epoch 5/50
# 26/26 - 7s - loss: 0.0118 - accuracy: 0.0460 - val_loss: 0.0118 - val_accuracy: 0.0396
# Epoch 6/50
# 26/26 - 7s - loss: 0.0113 - accuracy: 0.0671 - val_loss: 0.0110 - val_accuracy: 0.0347
# Epoch 7/50
# 26/26 - 7s - loss: 0.0137 - accuracy: 0.0646 - val_loss: 0.0166 - val_accuracy: 0.0198
# Epoch 8/50
# 26/26 - 7s - loss: 0.0135 - accuracy: 0.0509 - val_loss: 0.0130 - val_accuracy: 0.0248
# Epoch 9/50
# 26/26 - 7s - loss: 0.0120 - accuracy: 0.0422 - val_loss: 0.0117 - val_accuracy: 0.0594
# Epoch 10/50
# 26/26 - 7s - loss: 0.0113 - accuracy: 0.0534 - val_loss: 0.0114 - val_accuracy: 0.0594
# Iternation # :  7
# Epoch 1/50
# 26/26 - 7s - loss: 0.0110 - accuracy: 0.0696 - val_loss: 0.0112 - val_accuracy: 0.0693
# Epoch 2/50
# 26/26 - 7s - loss: 0.0109 - accuracy: 0.0634 - val_loss: 0.0107 - val_accuracy: 0.0891
# Epoch 3/50
# 26/26 - 7s - loss: 0.0104 - accuracy: 0.0770 - val_loss: 0.0101 - val_accuracy: 0.0842
# Epoch 4/50
# 26/26 - 7s - loss: 0.0102 - accuracy: 0.0783 - val_loss: 0.0101 - val_accuracy: 0.0990
# Epoch 5/50
# 26/26 - 7s - loss: 0.0099 - accuracy: 0.0807 - val_loss: 0.0100 - val_accuracy: 0.0792
# Epoch 6/50
# 26/26 - 7s - loss: 0.0096 - accuracy: 0.0832 - val_loss: 0.0095 - val_accuracy: 0.0990
# Epoch 7/50
# 26/26 - 7s - loss: 0.0091 - accuracy: 0.0832 - val_loss: 0.0092 - val_accuracy: 0.0792
# Epoch 8/50
# 26/26 - 7s - loss: 0.0088 - accuracy: 0.0621 - val_loss: 0.0091 - val_accuracy: 0.0594
# Epoch 9/50
# 26/26 - 7s - loss: 0.0088 - accuracy: 0.0634 - val_loss: 0.0093 - val_accuracy: 0.0842
# Epoch 10/50
# 26/26 - 7s - loss: 0.0087 - accuracy: 0.0609 - val_loss: 0.0091 - val_accuracy: 0.0693
# Epoch 11/50
# 26/26 - 7s - loss: 0.0084 - accuracy: 0.0820 - val_loss: 0.0087 - val_accuracy: 0.0990
# Epoch 12/50
# 26/26 - 7s - loss: 0.0082 - accuracy: 0.0745 - val_loss: 0.0087 - val_accuracy: 0.1139
# Epoch 13/50
# 26/26 - 7s - loss: 0.0082 - accuracy: 0.0770 - val_loss: 0.0085 - val_accuracy: 0.1337
# Epoch 14/50
# 26/26 - 7s - loss: 0.0082 - accuracy: 0.0745 - val_loss: 0.0085 - val_accuracy: 0.1337
# Epoch 15/50
# 26/26 - 7s - loss: 0.0081 - accuracy: 0.0807 - val_loss: 0.0085 - val_accuracy: 0.1089
# Epoch 16/50
# 26/26 - 7s - loss: 0.0080 - accuracy: 0.0845 - val_loss: 0.0083 - val_accuracy: 0.1238
# Epoch 17/50
# 26/26 - 7s - loss: 0.0079 - accuracy: 0.0870 - val_loss: 0.0083 - val_accuracy: 0.1139
# Epoch 18/50
# 26/26 - 7s - loss: 0.0078 - accuracy: 0.0857 - val_loss: 0.0082 - val_accuracy: 0.1386
# Epoch 19/50
# 26/26 - 7s - loss: 0.0078 - accuracy: 0.0857 - val_loss: 0.0084 - val_accuracy: 0.0990
# Epoch 20/50
# 26/26 - 7s - loss: 0.0078 - accuracy: 0.0932 - val_loss: 0.0081 - val_accuracy: 0.1188
# Epoch 21/50
# 26/26 - 7s - loss: 0.0077 - accuracy: 0.0919 - val_loss: 0.0079 - val_accuracy: 0.1188
# Epoch 22/50
# 26/26 - 7s - loss: 0.0075 - accuracy: 0.1031 - val_loss: 0.0079 - val_accuracy: 0.1238
# Epoch 23/50
# 26/26 - 7s - loss: 0.0075 - accuracy: 0.0932 - val_loss: 0.0078 - val_accuracy: 0.1238
# Epoch 24/50
# 26/26 - 7s - loss: 0.0075 - accuracy: 0.1043 - val_loss: 0.0078 - val_accuracy: 0.1139
# Epoch 25/50
# 26/26 - 7s - loss: 0.0074 - accuracy: 0.0957 - val_loss: 0.0077 - val_accuracy: 0.1089
# Epoch 26/50
# 26/26 - 7s - loss: 0.0073 - accuracy: 0.1106 - val_loss: 0.0077 - val_accuracy: 0.1535
# Epoch 27/50
# 26/26 - 7s - loss: 0.0073 - accuracy: 0.0907 - val_loss: 0.0077 - val_accuracy: 0.1188
# Epoch 28/50
# 26/26 - 7s - loss: 0.0073 - accuracy: 0.0981 - val_loss: 0.0077 - val_accuracy: 0.1188
# Epoch 29/50
# 26/26 - 7s - loss: 0.0073 - accuracy: 0.1056 - val_loss: 0.0076 - val_accuracy: 0.1485
# Epoch 30/50
# 26/26 - 7s - loss: 0.0072 - accuracy: 0.1019 - val_loss: 0.0076 - val_accuracy: 0.1337
# Epoch 31/50
# 26/26 - 7s - loss: 0.0072 - accuracy: 0.1081 - val_loss: 0.0075 - val_accuracy: 0.1238
# Epoch 32/50
# 26/26 - 7s - loss: 0.0071 - accuracy: 0.1168 - val_loss: 0.0074 - val_accuracy: 0.1485
# Epoch 33/50
# 26/26 - 7s - loss: 0.0071 - accuracy: 0.0907 - val_loss: 0.0074 - val_accuracy: 0.1386
# Epoch 34/50
# 26/26 - 7s - loss: 0.0071 - accuracy: 0.1019 - val_loss: 0.0075 - val_accuracy: 0.1238
# Epoch 35/50
# 26/26 - 7s - loss: 0.0071 - accuracy: 0.1081 - val_loss: 0.0073 - val_accuracy: 0.1386
# Epoch 36/50
# 26/26 - 7s - loss: 0.0070 - accuracy: 0.1217 - val_loss: 0.0073 - val_accuracy: 0.1188
# Epoch 37/50
# 26/26 - 7s - loss: 0.0070 - accuracy: 0.1068 - val_loss: 0.0073 - val_accuracy: 0.1089
# Epoch 38/50
# 26/26 - 7s - loss: 0.0070 - accuracy: 0.1242 - val_loss: 0.0073 - val_accuracy: 0.1386
# Epoch 39/50
# 26/26 - 7s - loss: 0.0069 - accuracy: 0.1205 - val_loss: 0.0073 - val_accuracy: 0.1337
# Epoch 40/50
# 26/26 - 7s - loss: 0.0069 - accuracy: 0.1180 - val_loss: 0.0072 - val_accuracy: 0.1485
# Epoch 41/50
# 26/26 - 7s - loss: 0.0069 - accuracy: 0.1292 - val_loss: 0.0073 - val_accuracy: 0.1139
# Epoch 42/50
# 26/26 - 7s - loss: 0.0070 - accuracy: 0.1118 - val_loss: 0.0073 - val_accuracy: 0.1040
# Epoch 43/50
# 26/26 - 7s - loss: 0.0069 - accuracy: 0.1280 - val_loss: 0.0072 - val_accuracy: 0.1238
# Epoch 44/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1205 - val_loss: 0.0072 - val_accuracy: 0.1535
# Epoch 45/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1366 - val_loss: 0.0071 - val_accuracy: 0.1485
# Epoch 46/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1342 - val_loss: 0.0071 - val_accuracy: 0.1337
# Epoch 47/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1342 - val_loss: 0.0071 - val_accuracy: 0.1287
# Epoch 48/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1317 - val_loss: 0.0071 - val_accuracy: 0.1337
# Epoch 49/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1342 - val_loss: 0.0071 - val_accuracy: 0.1386
# Epoch 50/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1329 - val_loss: 0.0071 - val_accuracy: 0.1337
# Iternation # :  8
# Epoch 1/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1379 - val_loss: 0.0071 - val_accuracy: 0.1139
# Epoch 2/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1478 - val_loss: 0.0070 - val_accuracy: 0.1188
# Epoch 3/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1429 - val_loss: 0.0070 - val_accuracy: 0.1238
# Epoch 4/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1366 - val_loss: 0.0077 - val_accuracy: 0.1386
# Epoch 5/50
# 26/26 - 7s - loss: 0.0071 - accuracy: 0.1255 - val_loss: 0.0073 - val_accuracy: 0.1287
# Epoch 6/50
# 26/26 - 7s - loss: 0.0068 - accuracy: 0.1304 - val_loss: 0.0071 - val_accuracy: 0.1287
# Epoch 7/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1366 - val_loss: 0.0070 - val_accuracy: 0.1535
# Iternation # :  9
# Epoch 1/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1391 - val_loss: 0.0071 - val_accuracy: 0.1386
# Epoch 2/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1416 - val_loss: 0.0070 - val_accuracy: 0.1386
# Epoch 3/50
# 26/26 - 7s - loss: 0.0066 - accuracy: 0.1441 - val_loss: 0.0070 - val_accuracy: 0.1188
# Epoch 4/50
# 26/26 - 7s - loss: 0.0066 - accuracy: 0.1255 - val_loss: 0.0071 - val_accuracy: 0.1634
# Epoch 5/50
# 26/26 - 7s - loss: 0.0067 - accuracy: 0.1317 - val_loss: 0.0070 - val_accuracy: 0.1436
# Epoch 6/50
# 26/26 - 7s - loss: 0.0066 - accuracy: 0.1453 - val_loss: 0.0069 - val_accuracy: 0.1386
# Epoch 7/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1404 - val_loss: 0.0069 - val_accuracy: 0.1386
# Epoch 8/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1429 - val_loss: 0.0069 - val_accuracy: 0.1287
# Epoch 9/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1429 - val_loss: 0.0069 - val_accuracy: 0.1238
# Epoch 10/50
# 26/26 - 7s - loss: 0.0066 - accuracy: 0.1491 - val_loss: 0.0069 - val_accuracy: 0.1584
# Epoch 11/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1478 - val_loss: 0.0069 - val_accuracy: 0.1386
# Epoch 12/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1540 - val_loss: 0.0068 - val_accuracy: 0.1238
# Epoch 13/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1553 - val_loss: 0.0069 - val_accuracy: 0.1337
# Epoch 14/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1391 - val_loss: 0.0068 - val_accuracy: 0.1188
# Epoch 15/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1615 - val_loss: 0.0068 - val_accuracy: 0.1386
# Epoch 16/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1391 - val_loss: 0.0068 - val_accuracy: 0.1436
# Epoch 17/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1429 - val_loss: 0.0069 - val_accuracy: 0.1634
# Epoch 18/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1441 - val_loss: 0.0069 - val_accuracy: 0.1287
# Epoch 19/50
# 26/26 - 7s - loss: 0.0065 - accuracy: 0.1503 - val_loss: 0.0068 - val_accuracy: 0.1485
# Iternation # :  10
# Epoch 1/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1503 - val_loss: 0.0067 - val_accuracy: 0.1287
# Epoch 2/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1602 - val_loss: 0.0067 - val_accuracy: 0.1535
# Epoch 3/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1602 - val_loss: 0.0068 - val_accuracy: 0.1485
# Epoch 4/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1516 - val_loss: 0.0068 - val_accuracy: 0.1634
# Epoch 5/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1416 - val_loss: 0.0069 - val_accuracy: 0.1485
# Epoch 6/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1553 - val_loss: 0.0068 - val_accuracy: 0.1337
# Iternation # :  11
# Epoch 1/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1578 - val_loss: 0.0068 - val_accuracy: 0.1436
# Epoch 2/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1516 - val_loss: 0.0067 - val_accuracy: 0.1535
# Epoch 3/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1578 - val_loss: 0.0067 - val_accuracy: 0.1683
# Epoch 4/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1466 - val_loss: 0.0067 - val_accuracy: 0.1634
# Epoch 5/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1553 - val_loss: 0.0068 - val_accuracy: 0.1386
# Epoch 6/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1640 - val_loss: 0.0068 - val_accuracy: 0.1238
# Epoch 7/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1752 - val_loss: 0.0068 - val_accuracy: 0.1485
# Epoch 8/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1652 - val_loss: 0.0068 - val_accuracy: 0.1386
# Iternation # :  12
# Epoch 1/50
# 26/26 - 7s - loss: 0.0064 - accuracy: 0.1528 - val_loss: 0.0067 - val_accuracy: 0.1188
# Epoch 2/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1727 - val_loss: 0.0067 - val_accuracy: 0.1337
# Epoch 3/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1677 - val_loss: 0.0067 - val_accuracy: 0.1535
# Epoch 4/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1652 - val_loss: 0.0067 - val_accuracy: 0.1584
# Epoch 5/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1677 - val_loss: 0.0067 - val_accuracy: 0.1386
# Epoch 6/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1627 - val_loss: 0.0067 - val_accuracy: 0.1386
# Epoch 7/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1565 - val_loss: 0.0067 - val_accuracy: 0.1337
# Epoch 8/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1801 - val_loss: 0.0067 - val_accuracy: 0.1337
# Epoch 9/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1565 - val_loss: 0.0066 - val_accuracy: 0.1386
# Epoch 10/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1776 - val_loss: 0.0066 - val_accuracy: 0.1089
# Epoch 11/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1627 - val_loss: 0.0066 - val_accuracy: 0.1683
# Epoch 12/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1739 - val_loss: 0.0066 - val_accuracy: 0.1386
# Epoch 13/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1901 - val_loss: 0.0066 - val_accuracy: 0.1436
# Epoch 14/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1776 - val_loss: 0.0066 - val_accuracy: 0.1436
# Epoch 15/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1988 - val_loss: 0.0066 - val_accuracy: 0.1436
# Epoch 16/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1851 - val_loss: 0.0066 - val_accuracy: 0.1436
# Epoch 17/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1776 - val_loss: 0.0066 - val_accuracy: 0.1337
# Epoch 18/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1988 - val_loss: 0.0066 - val_accuracy: 0.1089
# Epoch 19/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1727 - val_loss: 0.0066 - val_accuracy: 0.1287
# Iternation # :  13
# Epoch 1/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1863 - val_loss: 0.0066 - val_accuracy: 0.1337
# Epoch 2/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1714 - val_loss: 0.0066 - val_accuracy: 0.1139
# Epoch 3/50
# 26/26 - 7s - loss: 0.0063 - accuracy: 0.1814 - val_loss: 0.0066 - val_accuracy: 0.1386
# Epoch 4/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1863 - val_loss: 0.0066 - val_accuracy: 0.1386
# Epoch 5/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1826 - val_loss: 0.0065 - val_accuracy: 0.0990
# Epoch 6/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1764 - val_loss: 0.0066 - val_accuracy: 0.1139
# Epoch 7/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1789 - val_loss: 0.0065 - val_accuracy: 0.1089
# Epoch 8/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1876 - val_loss: 0.0065 - val_accuracy: 0.1337
# Epoch 9/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1826 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 10/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1901 - val_loss: 0.0065 - val_accuracy: 0.1337
# Epoch 11/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1938 - val_loss: 0.0066 - val_accuracy: 0.1535
# Epoch 12/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1826 - val_loss: 0.0066 - val_accuracy: 0.1287
# Epoch 13/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1752 - val_loss: 0.0065 - val_accuracy: 0.1287
# Iternation # :  14
# Epoch 1/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1727 - val_loss: 0.0066 - val_accuracy: 0.1188
# Epoch 2/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1913 - val_loss: 0.0066 - val_accuracy: 0.1337
# Epoch 3/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1826 - val_loss: 0.0066 - val_accuracy: 0.1386
# Epoch 4/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1714 - val_loss: 0.0066 - val_accuracy: 0.1238
# Epoch 5/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.1950 - val_loss: 0.0065 - val_accuracy: 0.1386
# Iternation # :  15
# Epoch 1/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1888 - val_loss: 0.0065 - val_accuracy: 0.1188
# Epoch 2/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2000 - val_loss: 0.0065 - val_accuracy: 0.1188
# Epoch 3/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1801 - val_loss: 0.0065 - val_accuracy: 0.1188
# Epoch 4/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1975 - val_loss: 0.0065 - val_accuracy: 0.1337
# Epoch 5/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2025 - val_loss: 0.0065 - val_accuracy: 0.1139
# Epoch 6/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2099 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 7/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1975 - val_loss: 0.0065 - val_accuracy: 0.1188
# Iternation # :  16
# Epoch 1/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2124 - val_loss: 0.0065 - val_accuracy: 0.1337
# Epoch 2/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2000 - val_loss: 0.0065 - val_accuracy: 0.1188
# Epoch 3/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1913 - val_loss: 0.0065 - val_accuracy: 0.1287
# Epoch 4/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2149 - val_loss: 0.0065 - val_accuracy: 0.1287
# Epoch 5/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1863 - val_loss: 0.0065 - val_accuracy: 0.1386
# Epoch 6/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2087 - val_loss: 0.0065 - val_accuracy: 0.1584
# Epoch 7/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1814 - val_loss: 0.0065 - val_accuracy: 0.1683
# Epoch 8/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2112 - val_loss: 0.0065 - val_accuracy: 0.1485
# Epoch 9/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1938 - val_loss: 0.0064 - val_accuracy: 0.1337
# Epoch 10/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.1913 - val_loss: 0.0064 - val_accuracy: 0.1436
# Epoch 11/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.1950 - val_loss: 0.0065 - val_accuracy: 0.1287
# Epoch 12/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2012 - val_loss: 0.0064 - val_accuracy: 0.1584
# Epoch 13/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.1988 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 14/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2062 - val_loss: 0.0064 - val_accuracy: 0.1337
# Epoch 15/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2124 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 16/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2087 - val_loss: 0.0064 - val_accuracy: 0.1386
# Epoch 17/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.1950 - val_loss: 0.0065 - val_accuracy: 0.1188
# Iternation # :  17
# Epoch 1/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2099 - val_loss: 0.0065 - val_accuracy: 0.1287
# Epoch 2/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2124 - val_loss: 0.0065 - val_accuracy: 0.1337
# Epoch 3/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2025 - val_loss: 0.0064 - val_accuracy: 0.1287
# Epoch 4/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2112 - val_loss: 0.0064 - val_accuracy: 0.1238
# Epoch 5/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2050 - val_loss: 0.0064 - val_accuracy: 0.1188
# Epoch 6/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2161 - val_loss: 0.0065 - val_accuracy: 0.1089
# Epoch 7/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2037 - val_loss: 0.0065 - val_accuracy: 0.1386
# Iternation # :  18
# Epoch 1/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2161 - val_loss: 0.0067 - val_accuracy: 0.1287
# Epoch 2/50
# 26/26 - 7s - loss: 0.0062 - accuracy: 0.2174 - val_loss: 0.0066 - val_accuracy: 0.1238
# Epoch 3/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2211 - val_loss: 0.0065 - val_accuracy: 0.1040
# Epoch 4/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2099 - val_loss: 0.0065 - val_accuracy: 0.1436
# Epoch 5/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2174 - val_loss: 0.0065 - val_accuracy: 0.1436
# Epoch 6/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2112 - val_loss: 0.0065 - val_accuracy: 0.1436
# Epoch 7/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2050 - val_loss: 0.0065 - val_accuracy: 0.1040
# Epoch 8/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2174 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 9/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2174 - val_loss: 0.0065 - val_accuracy: 0.1287
# Iternation # :  19
# Epoch 1/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2236 - val_loss: 0.0065 - val_accuracy: 0.1238
# Epoch 2/50
# 26/26 - 7s - loss: 0.0061 - accuracy: 0.2099 - val_loss: 0.0064 - val_accuracy: 0.1238
# Epoch 3/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2373 - val_loss: 0.0064 - val_accuracy: 0.0990
# Epoch 4/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2348 - val_loss: 0.0064 - val_accuracy: 0.1287
# Epoch 5/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2050 - val_loss: 0.0064 - val_accuracy: 0.1287
# Epoch 6/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2137 - val_loss: 0.0064 - val_accuracy: 0.1386
# Epoch 7/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2000 - val_loss: 0.0064 - val_accuracy: 0.1287
# Epoch 8/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2211 - val_loss: 0.0064 - val_accuracy: 0.1634
# Epoch 9/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2199 - val_loss: 0.0064 - val_accuracy: 0.1188
# Iternation # :  20
# Epoch 1/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2335 - val_loss: 0.0064 - val_accuracy: 0.1089
# Epoch 2/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2323 - val_loss: 0.0064 - val_accuracy: 0.1188
# Epoch 3/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2323 - val_loss: 0.0064 - val_accuracy: 0.1386
# Epoch 4/50
# 26/26 - 7s - loss: 0.0060 - accuracy: 0.2161 - val_loss: 0.0064 - val_accuracy: 0.1535
# Epoch 5/50
# 26/26 - 7s - loss: 0.0059 - accuracy: 0.2323 - val_loss: 0.0047 - val_accuracy: 0.1188
# Epoch 6/50
# 26/26 - 7s - loss: 0.0041 - accuracy: 0.1814 - val_loss: 0.0041 - val_accuracy: 0.1287
# Epoch 7/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.1975 - val_loss: 0.0040 - val_accuracy: 0.1386
# Epoch 8/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2273 - val_loss: 0.0040 - val_accuracy: 0.1337
# Epoch 9/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2385 - val_loss: 0.0040 - val_accuracy: 0.1485
# Epoch 10/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2137 - val_loss: 0.0040 - val_accuracy: 0.1287
# Epoch 11/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2161 - val_loss: 0.0039 - val_accuracy: 0.1337
# Epoch 12/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2335 - val_loss: 0.0040 - val_accuracy: 0.1287
# Epoch 13/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2224 - val_loss: 0.0040 - val_accuracy: 0.1188
# Epoch 14/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2261 - val_loss: 0.0040 - val_accuracy: 0.1584
# Epoch 15/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2124 - val_loss: 0.0040 - val_accuracy: 0.1287
# Epoch 16/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2385 - val_loss: 0.0040 - val_accuracy: 0.1535
# Iternation # :  21
# Epoch 1/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2385 - val_loss: 0.0039 - val_accuracy: 0.1139
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2050 - val_loss: 0.0040 - val_accuracy: 0.1485
# Epoch 3/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2348 - val_loss: 0.0040 - val_accuracy: 0.1238
# Epoch 4/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2199 - val_loss: 0.0040 - val_accuracy: 0.1287
# Epoch 5/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2311 - val_loss: 0.0040 - val_accuracy: 0.1386
# Epoch 6/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2348 - val_loss: 0.0039 - val_accuracy: 0.1238
# Iternation # :  22
# Epoch 1/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2460 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2497 - val_loss: 0.0040 - val_accuracy: 0.1436
# Epoch 3/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2360 - val_loss: 0.0039 - val_accuracy: 0.1139
# Epoch 4/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2311 - val_loss: 0.0040 - val_accuracy: 0.1584
# Epoch 5/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2174 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 6/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2248 - val_loss: 0.0039 - val_accuracy: 0.1436
# Iternation # :  23
# Epoch 1/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2472 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2360 - val_loss: 0.0039 - val_accuracy: 0.1386
# Epoch 3/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2323 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 4/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2298 - val_loss: 0.0040 - val_accuracy: 0.1683
# Epoch 5/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2398 - val_loss: 0.0041 - val_accuracy: 0.1535
# Epoch 6/50
# 26/26 - 7s - loss: 0.0037 - accuracy: 0.2385 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 7/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2323 - val_loss: 0.0039 - val_accuracy: 0.1584
# Iternation # :  24
# Epoch 1/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2335 - val_loss: 0.0039 - val_accuracy: 0.1535
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2559 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 3/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2373 - val_loss: 0.0039 - val_accuracy: 0.1436
# Epoch 4/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2435 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 5/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2211 - val_loss: 0.0039 - val_accuracy: 0.1683
# Epoch 6/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2435 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 7/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2186 - val_loss: 0.0039 - val_accuracy: 0.1386
# Epoch 8/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2286 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 9/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2410 - val_loss: 0.0039 - val_accuracy: 0.1832
# Epoch 10/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2261 - val_loss: 0.0039 - val_accuracy: 0.1733
# Epoch 11/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2398 - val_loss: 0.0039 - val_accuracy: 0.1733
# Epoch 12/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2596 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 13/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2509 - val_loss: 0.0039 - val_accuracy: 0.1881
# Epoch 14/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2298 - val_loss: 0.0039 - val_accuracy: 0.1535
# Epoch 15/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2559 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 16/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2248 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 17/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2224 - val_loss: 0.0040 - val_accuracy: 0.1634
# Iternation # :  25
# Epoch 1/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2211 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2398 - val_loss: 0.0039 - val_accuracy: 0.1733
# Epoch 3/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2547 - val_loss: 0.0040 - val_accuracy: 0.1782
# Epoch 4/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2472 - val_loss: 0.0039 - val_accuracy: 0.1782
# Epoch 5/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2385 - val_loss: 0.0039 - val_accuracy: 0.1683
# Epoch 6/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2348 - val_loss: 0.0039 - val_accuracy: 0.1832
# Epoch 7/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2472 - val_loss: 0.0039 - val_accuracy: 0.1535
# Epoch 8/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2298 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 9/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2099 - val_loss: 0.0039 - val_accuracy: 0.1386
# Epoch 10/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2484 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 11/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2286 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 12/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2385 - val_loss: 0.0038 - val_accuracy: 0.1584
# Epoch 13/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2298 - val_loss: 0.0038 - val_accuracy: 0.1485
# Epoch 14/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2273 - val_loss: 0.0038 - val_accuracy: 0.1584
# Epoch 15/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2435 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 16/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2460 - val_loss: 0.0038 - val_accuracy: 0.1683
# Epoch 17/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2472 - val_loss: 0.0038 - val_accuracy: 0.1832
# Epoch 18/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2422 - val_loss: 0.0039 - val_accuracy: 0.1386
# Epoch 19/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2273 - val_loss: 0.0039 - val_accuracy: 0.1485
# Epoch 20/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2410 - val_loss: 0.0038 - val_accuracy: 0.1634
# Epoch 21/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2335 - val_loss: 0.0038 - val_accuracy: 0.1832
# Epoch 22/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2460 - val_loss: 0.0039 - val_accuracy: 0.1584
# Epoch 23/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2385 - val_loss: 0.0039 - val_accuracy: 0.1535
# Epoch 24/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2360 - val_loss: 0.0039 - val_accuracy: 0.1733
# Epoch 25/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2447 - val_loss: 0.0039 - val_accuracy: 0.1584
# Iternation # :  26
# Epoch 1/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2348 - val_loss: 0.0039 - val_accuracy: 0.1683
# Epoch 2/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2385 - val_loss: 0.0039 - val_accuracy: 0.1733
# Epoch 3/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2398 - val_loss: 0.0038 - val_accuracy: 0.1535
# Epoch 4/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2199 - val_loss: 0.0040 - val_accuracy: 0.1881
# Epoch 5/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2224 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 6/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2323 - val_loss: 0.0038 - val_accuracy: 0.1782
# Epoch 7/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2435 - val_loss: 0.0038 - val_accuracy: 0.1287
# Epoch 8/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2373 - val_loss: 0.0038 - val_accuracy: 0.1436
# Epoch 9/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2286 - val_loss: 0.0039 - val_accuracy: 0.1634
# Epoch 10/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2472 - val_loss: 0.0039 - val_accuracy: 0.1386
# Epoch 11/50
# 26/26 - 7s - loss: 0.0036 - accuracy: 0.2360 - val_loss: 0.0038 - val_accuracy: 0.1634
# Iternation # :  27
# Epoch 1/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2460 - val_loss: 0.0039 - val_accuracy: 0.1782
# Epoch 2/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2484 - val_loss: 0.0038 - val_accuracy: 0.1881
# Epoch 3/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2472 - val_loss: 0.0039 - val_accuracy: 0.1782
# Epoch 4/50
# 26/26 - 7s - loss: 0.0035 - accuracy: 0.2323 - val_loss: 0.0038 - val_accuracy: 0.1782
# Epoch 5/50
# 26/26 - 7s - loss: 0.0024 - accuracy: 0.2273 - val_loss: 8.9572e-04 - val_accuracy: 0.1485
# Epoch 6/50
# 26/26 - 7s - loss: 7.1844e-04 - accuracy: 0.2248 - val_loss: 7.7969e-04 - val_accuracy: 0.1535
# Epoch 7/50
# 26/26 - 7s - loss: 5.8644e-04 - accuracy: 0.2385 - val_loss: 6.9553e-04 - val_accuracy: 0.1634
# Epoch 8/50
# 26/26 - 7s - loss: 5.3693e-04 - accuracy: 0.2460 - val_loss: 6.8501e-04 - val_accuracy: 0.1832
# Epoch 9/50
# 26/26 - 7s - loss: 5.1057e-04 - accuracy: 0.2311 - val_loss: 6.3662e-04 - val_accuracy: 0.1634
# Epoch 10/50
# 26/26 - 7s - loss: 4.9887e-04 - accuracy: 0.2398 - val_loss: 6.6808e-04 - val_accuracy: 0.1881
# Epoch 11/50
# 26/26 - 7s - loss: 4.9086e-04 - accuracy: 0.2435 - val_loss: 6.3421e-04 - val_accuracy: 0.1634
# Epoch 12/50
# 26/26 - 7s - loss: 4.9257e-04 - accuracy: 0.2447 - val_loss: 6.9135e-04 - val_accuracy: 0.1584
# Epoch 13/50
# 26/26 - 7s - loss: 5.0252e-04 - accuracy: 0.2509 - val_loss: 6.5955e-04 - val_accuracy: 0.1634
# Epoch 14/50
# 26/26 - 7s - loss: 5.0861e-04 - accuracy: 0.2335 - val_loss: 6.5054e-04 - val_accuracy: 0.1634
# Epoch 15/50
# 26/26 - 7s - loss: 5.0296e-04 - accuracy: 0.2571 - val_loss: 6.5230e-04 - val_accuracy: 0.1683
# Iternation # :  28
# Epoch 1/50
# 26/26 - 7s - loss: 5.1567e-04 - accuracy: 0.2199 - val_loss: 6.5710e-04 - val_accuracy: 0.1683
# Epoch 2/50
# 26/26 - 7s - loss: 5.2161e-04 - accuracy: 0.2460 - val_loss: 7.0404e-04 - val_accuracy: 0.1535
# Epoch 3/50
# 26/26 - 7s - loss: 5.4119e-04 - accuracy: 0.2435 - val_loss: 0.0014 - val_accuracy: 0.1089

# %% [markdown]
# Plotting the learning curve - Loss

# %%
plt.figure(figsize = (15,10))

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize = (15,10))

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Predicting Test Results

# %%
X_test, void = processData(PCA_test,lookback,horizon,num_companies,horizon)
void, y_test = processData(array_test,lookback,horizon,num_companies,horizon) 
y_test = np.array([list(a.ravel()) for a in y_test])


Xt = model.predict(X_test)
Xt.shape

# %% [markdown]
# ### Un-scaling the data and returning data to original shape
# Because the results were scaled to train the model, the output is non sensible until we return the data into its original form

# %%
#Aux function 1
def do_inverse_transform(output_result,num_companies):
    #transform to input shape
    
    original_matrix_format = []
    for result in output_result:
        #do inverse transform
        original_matrix_format.append(scl_array_train.inverse_transform([result[x:x+num_companies] for x in range(0, len(result), num_companies)]))
    original_matrix_format = np.array(original_matrix_format)
    
    #restore to original shape
    for i in range(len(original_matrix_format)):
        output_result[i] = original_matrix_format[i].ravel()

    return output_result

# %%
#Aux function 2
def prediction_by_step_by_company(raw_model_output, num_companies):
    matrix_prediction = []
    for i in range(0,num_companies):
        matrix_prediction.append([[lista[j] for j in range(i,len(lista),num_companies)] for lista in raw_model_output])
    return np.array(matrix_prediction)

# %%
#Aux function 3
def target_by_company(raw_model_output, num_companies):
    matrix_target = [[] for x in range(num_companies)]
    
    for output in raw_model_output:
        for i in range (num_companies):
            for j in range(0,len(output),num_companies):
                matrix_target[i].append(output[i+j])
    return np.array(matrix_target)

# %%
Xt = do_inverse_transform(Xt, num_companies)
predictions = prediction_by_step_by_company(Xt, num_companies)
predictions.shape

# %%
Yt = do_inverse_transform(y_test, num_companies)

actuals = target_by_company(Yt, num_companies)
actuals.shape

# %% [markdown]
# ### Prediction Results on Test Data - Plot

# %%
plt.figure(figsize = (15,10))

companies_to_show = [0] #Type a number between 0:4 to see 4 different companies
colors = ['r','g','c','m','y','k','w','b']
companies_names = ["BAC","IBM","PFE","TSLA","XOM"]
 
for id_company in companies_to_show:
    for i in range(0,len(predictions[id_company])):
        plt.plot([x + i*horizon for x in range(len(predictions[id_company][i]))], predictions[id_company][i], color=colors[id_company])
    plt.plot(0,predictions[id_company][0][0] ,color=colors[id_company], label='predict_{}'.format(companies_names[id_company])) #only to place the label

   

for id_company in companies_to_show:
    plt.plot(actuals[id_company], label='target_{}'.format(companies_names[id_company]))

plt.legend(loc='best')
plt.show()

# %%
full_PCA = np.concatenate((PCA_train,PCA_test),axis = 0)

# %%
X_all,void = processData(full_PCA,lookback,horizon,num_companies,horizon)
void,y_all = processData(scl_array_train.fit_transform(df_close),lookback,horizon,num_companies,horizon)
y_all = np.array([list(a.ravel()) for a in y_all])

# %%
Xt = model.predict(X_all)
Xt.shape

# %%
Xt = do_inverse_transform(Xt, num_companies)

predictions = prediction_by_step_by_company(Xt, num_companies)
predictions.shape

# %%
Yt = do_inverse_transform(y_all, num_companies)

actuals = target_by_company(Yt, num_companies)
actuals.shape

# %% [markdown]
# ### Prediction Results on Full Data - Plot

# %%
plt.figure(figsize = (40,10))

companies_to_show = [0] #Type a number between 0:4 to see 4 different companies
colors = ['r','g','c','m','y','k','w','b']
companies_names = ["BAC","IBM","PFE","TSLA","XOM"]

    
for id_company in companies_to_show:
    for i in range(0,len(predictions[id_company])):
        plt.plot([x + i*horizon for x in range(len(predictions[id_company][i]))], predictions[id_company][i], color=colors[id_company])
    plt.plot(0,predictions[id_company][0][0] ,color=colors[id_company], label='predict_{}'.format(companies_names[id_company])) #only to place the label

   

for id_company in companies_to_show:
    plt.plot(actuals[id_company], label='target_{}'.format(companies_names[id_company]))

plt.legend(loc='best')
plt.show()

##QQ-plot

# %% [markdown]
# # Stock Prices Predictions

# %%
predicted_prices = np.zeros((predictions.shape[1]*predictions.shape[2],predictions.shape[0]))
# actual_prices = []

for i in range(predictions.shape[0]):
  counter = 0
  for j in range(predictions.shape[1]):
    for z in range(predictions.shape[2]):
      predicted_prices[counter, i] = predictions[i,j,z]
      counter+=1

print(counter)

# %%
actuals_prices = actuals[:,:counter].T

# %%
print(predicted_prices.shape)
print(actuals_prices.shape)
print(dates.shape)

# %%
dates.shape[0]-lookback-counter

# %%
# Need to remove certain days because we predict into the future. But, we aren't able to test these predicted days
# against actual days in our porfolio optimization

actual_prices = pd.DataFrame(data = actuals_prices, columns = stocks,index = dates[lookback+1:1511-(dates.shape[0]-lookback -counter)])
predicted_prices = pd.DataFrame(data = predicted_prices,columns = stocks,index = dates[lookback+1:1511-(dates.shape[0]-lookback-counter)])

# %%
actual_prices.tail(5)

# %%
predicted_prices.tail(5)

# %%
predicted_prices.to_csv('PCA_Predicted_Prices.csv')

# %%
actual_prices.to_csv('PCA_Actual_Prices.csv')

# %%
#Model : LSTM
PCA_Predicted_Prices = pd.read_csv('PCA_Predicted_Prices.csv')
PCA_Predicted_Prices['Date'] =  pd.to_datetime(PCA_Predicted_Prices['Date'])
PCA_Predicted_Prices=PCA_Predicted_Prices.set_index('Date')

PCA_Actual_Prices = pd.read_csv('PCA_Actual_Prices.csv')
PCA_Actual_Prices['Date'] =  pd.to_datetime(PCA_Actual_Prices['Date'])
PCA_Actual_Prices=PCA_Actual_Prices.set_index('Date')

# %%
#Computing Log Returns
PCA_Predicted_Returns = PCA_Predicted_Prices.apply(lambda x: np.log(x) - np.log(x.shift(1))).iloc[1:] 
PCA_Actual_Returns = PCA_Actual_Prices.apply(lambda x: np.log(x) - np.log(x.shift(1))).iloc[1:]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(PCA_Actual_Prices, PCA_Predicted_Prices)

# %% [markdown]
# # Optimize Function Using SciPy

# %% [markdown]
# We run the optimization using the `scipy.optimization` module. This module has a function called `minimize` which we can use to help our optimial values. However, we need to do a few things before we run it.
# First, we need to define bounds which tells the `minimize` function that each of our positions can only be between 0% and 100% of the allocation.
# Second, we need to define the constraint which will be a function that ensures the sum of the weights is 100%. In other words, we use all the capital we can.
# Third, we need to define our initial guess of the weights. The initial guess can be anything but in this case we start with an equally distirbuted portofolio. We have 5 symbols so each symbol will be 20% of the portfolio.

# %%
# Calculate the Log of returns.
log_return = np.log(1 + predicted_prices.pct_change())

# Generate Random Weights.
random_weights = np.array(np.random.random(number_of_symbols))

# Generate the Rebalance Weights, these should equal 1.
rebalance_weights = random_weights / np.sum(random_weights)

# Calculate the Expected Returns, annualize it by multiplying it by `252`.
exp_ret = np.sum((log_return.mean() * rebalance_weights) * 252)

# Calculate the Expected Volatility, annualize it by multiplying it by `252`.
exp_vol = np.sqrt(
np.dot(
    rebalance_weights.T,
    np.dot(
        log_return.cov() * 252,
        rebalance_weights
    )
)
)

# Calculate the Sharpe Ratio.
sharpe_ratio = exp_ret / exp_vol

# Put the weights into a data frame to see them better.
weights_df = pd.DataFrame(data={
'random_weights': random_weights,
'rebalance_weights': rebalance_weights
})
print('')
print('='*80)
print('PORTFOLIO WEIGHTS:')
print('-'*80)
print(weights_df)
print('-'*80)

# Do the same with the other metrics.
metrics_df = pd.DataFrame(data={
    'Expected Portfolio Returns': exp_ret,
    'Expected Portfolio Volatility': exp_vol,
    'Portfolio Sharpe Ratio': sharpe_ratio
}, index=[0])

print('')
print('='*80)
print('PORTFOLIO METRICS:')
print('-'*80)
print(metrics_df)
print('-'*80)

# %%
def get_metrics(weights: list) -> np.array:
    """
    ### Overview:
    ----
    With a given set of weights, return the portfolio returns,
    the portfolio volatility, and the portfolio sharpe ratio.

    ### Arguments:
    ----
    weights (list): An array of portfolio weights.

    ### Returns:
    ----
    (np.array): An array containg return value, a volatility value,
        and a sharpe ratio.
    """

    # Convert to a Numpy Array.
    weights = np.array(weights)

    # Calculate the returns, remember to annualize them (252).
    ret = np.sum(log_return.mean() * weights) * 252

    # Calculate the volatility, remember to annualize them (252).
    vol = np.sqrt(
        np.dot(weights.T, np.dot(log_return.cov() * 252, weights))
    )

    # Calculate the Sharpe Ratio.
    sr = ret / vol

    return np.array([ret, vol, sr])

def grab_negative_sharpe(weights: list) -> np.array:
    """The function used to minimize the Sharpe Ratio.

    ### Arguments:
    ----
    weights (list): The weights, we are testing to see
        if it's the minimum.

    ### Returns:
    ----
    (np.array): An numpy array of the portfolio metrics.
    """
    return get_metrics(weights)[2] - 1

def grab_volatility(weights: list) -> np.array:
    """The function used to minimize the Sharpe Ratio.

    ### Arguments:
    ----
    weights (list): The weights, we are testing to see
        if it's the minimum.

    ### Returns:
    ----
    (np.array): An numpy array of the portfolio metrics.
    """
    return get_metrics(weights)[1]

def check_sum(weights: list) -> float:
    """Ensure the allocations of the "weights", sums to 1 (100%)

    ### Arguments:
    ----
    weights (list): The weights we want to check to see
        if they sum to 1.

    ### Returns:
    ----
    float: The different between 1 and the sum of the weights.
    """
    return np.sum(weights) - 1

# %% [markdown]
# Once we've define these steps we can run the optimization by passing through the arguments defined and using the method as `SLSQP` which is short for Sequential Least Squares Programming. Then we run the minimize method to grab the results.

# %%
# Define the boundaries for each symbol. Remember I can only invest up to 100% of my capital into a single asset.
bounds = tuple((0, 1) for symbol in range(number_of_symbols))

# Define the constraints, here I'm saying that the sum of each weight must not exceed 100%.
constraints = ({'type': 'eq', 'fun': check_sum})

# We need to create an initial guess to start with,
# and usually the best initial guess is just an
# even distribution. In this case 25% for each of the 4 stocks.
init_guess = number_of_symbols * [1 / number_of_symbols]

# Perform the operation to minimize the risk.
optimized_sharpe = sci_opt.minimize(
    grab_negative_sharpe, # minimize this.
    init_guess, # Start with these values.
    method='SLSQP',
    bounds=bounds, # don't exceed these bounds.
    constraints=constraints # make sure you don't exceed the 100% constraint.
)

# Print the results.
print('')
print('='*80)
print('OPTIMIZED SHARPE RATIO:')
print('-'*80)
print(optimized_sharpe)
print('-'*80)

# %% [markdown]
# The first is the results of our minimization operation. Inside the results, there is the optimize sharpe ration defined by the `fun` value. We can then take the `optimized_weights` defined in the `optimized_sharpe.x` values, and use them to return the different metrics we have for our portfolio.

# %%
# Grab the metrics.
optimized_metrics = get_metrics(weights=optimized_sharpe.x)

# Print the Optimized Weights.
print('')
print('='*80)
print('OPTIMIZED WEIGHTS:')
print('-'*80)
print(optimized_sharpe.x)
print('-'*80)


# Print the Optimized Metrics.
print('')
print('='*80)
print('OPTIMIZED METRICS:')
print('-'*80)
print(optimized_metrics)
print('-'*80)

# %%
# Define the boundaries for each symbol. Remember I can only invest up to 100% of my capital into a single asset.
bounds = tuple((0, 1) for symbol in range(number_of_symbols))

# Define the constraints, here I'm saying that the sum of each weight must not exceed 100%.
constraints = ({'type': 'eq', 'fun': check_sum})

# We need to create an initial guess to start with,
# and usually the best initial guess is just an
# even distribution. In this case 25% for each of the 4 stocks.
init_guess = number_of_symbols * [1 / number_of_symbols]

# Perform the operation to minimize the risk.
optimized_volatility = sci_opt.minimize(
    grab_volatility, # minimize this.
    init_guess, # Start with these values.
    method='SLSQP',
    bounds=bounds, # don't exceed these bounds.
    constraints=constraints # make sure you don't exceed the 100% constraint.
)

# Print the results.
print('')
print('='*80)
print('OPTIMIZED VOLATILITY RATIO:')
print('-'*80)
print(optimized_volatility)
print('-'*80)

# %%
# Grab the metrics.
optimized_metrics = get_metrics(weights=optimized_volatility.x)

# Print the Optimized Weights.
print('')
print('='*80)
print('OPTIMIZED WEIGHTS:')
print('-'*80)
print(optimized_volatility.x)
print('-'*80)


# Print the Optimized Metrics.
print('')
print('='*80)
print('OPTIMIZED METRICS:')
print('-'*80)
print(optimized_metrics)
print('-'*80)
